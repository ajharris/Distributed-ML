# %% [markdown]
# # Parquet Exploration Notebook
#
# To ensure the accurate representation of our datasets in Parquet format, we have created a dedicated Jupyter notebook. This notebook serves as a practical exploration tool to validate the structure and content of the Parquet files generated from our datasets.

# %%
import pandas as pd

df = pd.read_parquet("../../data/metadata/metadata_NLST.parquet")
print(df.head())
print(df.columns)
print(df.info())
# Out:
#   dataset_name patient_id                         scan_id    study_uid  \
# 0         NLST  NLST-0001  NLST__NLST-0001__1.2.3.4.100.1  1.2.3.4.100
# 1         NLST  NLST-0002  NLST__NLST-0002__1.2.3.4.200.1  1.2.3.4.200
#
#       series_uid modality acquisition_date  slice_thickness_mm  spacing_x_mm  \
# 0  1.2.3.4.100.1       CT       2005-03-12                1.25          0.70
# 1  1.2.3.4.200.1       CT       2006-03-15                1.00          0.68
#
#    spacing_y_mm  ...  fev1_percent_pred  fvc_l  fev1_fvc_ratio  gold_stage  \
# 0          0.70  ...               None   None            None        None
# 1          0.68  ...               None   None            None        None
#
#   copd_status emphysema_percent mortality_5yr mortality_6yr  \
# 0        None              None          None          None
# 1        None              None          None          None
#
#   lung_cancer_diagnosis other_clinical_json
# 0                  None                None
# ...
